# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# VOTES

# Read in voting data and set up initial voting dataframe

df_votes = pd.read_csv("../data_sources/elections_by_county_Eric.csv")
df_votes.head()
# Out:
#       county state  percentage16_Donald_Trump  percentage16_Hillary_Clinton  \
# 0  Abbeville    SC                      0.629                         0.346
# 1     Acadia    LA                      0.773                         0.206
# 2   Accomack    VA                      0.545                         0.428
# 3        Ada    ID                      0.479                         0.387
# 4      Adair    IA                      0.653                         0.300
#
#    total_votes16  votes16_Donald_Trump  votes16_Hillary_Clinton  \
# 0        10724.0                6742.0                   3712.0
# 1        27386.0               21159.0                   5638.0
# 2        15755.0                8582.0                   6737.0
# 3       195587.0               93748.0                  75676.0
# 4         3759.0                2456.0                   1127.0
#
#    percentage20_Donald_Trump  percentage20_Joe_Biden  total_votes20  ...  \
# ...

# %%
# Find full list of column names

for col in df_votes.columns:
    print(col)
# Out:
# county
# state
# percentage16_Donald_Trump
# percentage16_Hillary_Clinton
# total_votes16
# votes16_Donald_Trump
# votes16_Hillary_Clinton
# percentage20_Donald_Trump
# percentage20_Joe_Biden
# total_votes20
# votes20_Donald_Trump
# votes20_Joe_Biden
# lat
# long
# cases
# deaths
# TotalPop
# Men
# Women
# Hispanic
# White
# Black
# Native
# Asian
# Pacific
# VotingAgeCitizen
# Income
# IncomeErr
# IncomePerCap
# IncomePerCapErr
# Poverty
# ChildPoverty
# Professional
# Service
# Office
# Construction
# Production
# Drive
# Carpool
# Transit
# Walk
# OtherTransp
# WorkAtHome
# MeanCommute
# Employed
# PrivateWork
# PublicWork
# SelfEmployed
# FamilyWork
# UnemploymentCategorical

# %%
# select oregon voting data
df_OR_votes = df_votes[df_votes.state == 'OR']
df_OR_votes.head()
# Out:
#         county state  percentage16_Donald_Trump  percentage16_Hillary_Clinton  \
# 115      Baker    OR                      0.727                         0.210
# 183     Benton    OR                      0.286                         0.624
# 507  Clackamas    OR                      0.434                         0.495
# 532    Clatsop    OR                      0.429                         0.490
# 604   Columbia    OR                      0.517                         0.397
#
#      total_votes16  votes16_Donald_Trump  votes16_Hillary_Clinton  \
# 115         8479.0                6160.0                   1781.0
# 183        45577.0               13030.0                  28431.0
# 507       182136.0               79062.0                  90187.0
# 532        18158.0                7794.0                   8899.0
# 604        25077.0               12967.0                   9959.0
#
#      percentage20_Donald_Trump  percentage20_Joe_Biden  total_votes20  ...  \
# ...

# %%
# Deaths

# read in Death data and prep initial dataframe

df_deaths = pd.read_csv("../data_sources/Provisional_COVID-19_Death_Counts_in_the_United_States_by_County.csv")

df_deaths= df_deaths.rename(columns={'Date as of':'Date-as-of', 'Start Date':'Start_date', 'End Date': 'End_date', 'State':'state',
                            'County name':'CountyName', 'FIPS County Code':'FIPS_code', 'Urban Rural Code':'Urban-Rural_code',
                           'Deaths involving COVID-19':'Deaths_COVID', 'Deaths from All Causes':'Deaths_All'})

df_deaths.head()
# Out:
#    Date-as-of  Start_date    End_date state              CountyName  \
# 0  10/20/2021  01/01/2020  10/16/2021    AK  Aleutians East Borough
# 1  10/20/2021  01/01/2020  10/16/2021    AK  Anchorage Municipality
# 2  10/20/2021  01/01/2020  10/16/2021    AK      Bethel Census Area
# 3  10/20/2021  01/01/2020  10/16/2021    AK          Denali Borough
# 4  10/20/2021  01/01/2020  10/16/2021    AK  Dillingham Census Area
#
#    FIPS_code Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 0       2013          Noncore           NaN        14.0
# 1       2020     Medium metro         366.0      4133.0
# 2       2050          Noncore          18.0       194.0
# 3       2068          Noncore           NaN        11.0
# 4       2070          Noncore           NaN        45.0
#
#                                             Footnote
# 0  One or more data cells have counts between 1-9...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
#select Oregon Death statistics

df_OR_deaths = df_deaths[df_deaths.state == 'OR']
df_OR_deaths.head()
# Out:
#       Date-as-of  Start_date    End_date state        CountyName  FIPS_code  \
# 2128  10/20/2021  01/01/2020  10/16/2021    OR      Baker County      41001
# 2129  10/20/2021  01/01/2020  10/16/2021    OR     Benton County      41003
# 2130  10/20/2021  01/01/2020  10/16/2021    OR  Clackamas County      41005
# 2131  10/20/2021  01/01/2020  10/16/2021    OR    Clatsop County      41007
# 2132  10/20/2021  01/01/2020  10/16/2021    OR   Columbia County      41009
#
#         Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 2128             Noncore           NaN       390.0
# 2129         Small metro          69.0      1300.0
# 2130  Large fringe metro         321.0      6544.0
# 2131        Micropolitan          20.0       724.0
# 2132  Large fringe metro          15.0       507.0
#
#                                                Footnote
# 2128  One or more data cells have counts between 1-9...
# 2129                                                NaN
# ...

# %%
df_OR_deaths[['county','Extra']] = df_OR_deaths.CountyName.str.split(" County",expand=True,)
df_OR_deaths.head()
# Out:
# C:\Users\abgar\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#       Date-as-of  Start_date    End_date state        CountyName  FIPS_code  \
# 2128  10/20/2021  01/01/2020  10/16/2021    OR      Baker County      41001
# 2129  10/20/2021  01/01/2020  10/16/2021    OR     Benton County      41003
# 2130  10/20/2021  01/01/2020  10/16/2021    OR  Clackamas County      41005
# 2131  10/20/2021  01/01/2020  10/16/2021    OR    Clatsop County      41007
# 2132  10/20/2021  01/01/2020  10/16/2021    OR   Columbia County      41009
#
#         Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 2128             Noncore           NaN       390.0
# ...

# %%
# Merge dataframes! (SOLVED -- soloution: splice on "County " not "County")

merged_orgeon = pd.merge(df_OR_votes,df_OR_deaths, how='left', on='county')

# %%
merged_orgeon
# Out:
#         county state_x  percentage16_Donald_Trump  \
# 0        Baker      OR                      0.727
# 1       Benton      OR                      0.286
# 2    Clackamas      OR                      0.434
# 3      Clatsop      OR                      0.429
# 4     Columbia      OR                      0.517
# 5         Coos      OR                      0.586
# 6        Crook      OR                      0.721
# 7        Curry      OR                      0.588
# 8    Deschutes      OR                      0.482
# 9      Douglas      OR                      0.664
# 10     Gilliam      OR                      0.674
# 11       Grant      OR                      0.764
# 12      Harney      OR                      0.754
# 13  Hood River      OR                      0.310
# 14     Jackson      OR                      0.511
# 15   Jefferson      OR                      0.601
# 16   Josephine      OR                      0.624
# 17     Klamath      OR                      0.690
# ...

# %%
# WHY AM I LOSING DATA? merging seems to create blank entries, what's going on? 
# USING "merged_orgeon = pd.merge(df_OR_votes,df_OR_deaths, how='left', on='county')

# %%
# solution 2 - different outline

# %%
df_OR_votes.merge(df_OR_deaths, on='county')
# Out:
#         county state_x  percentage16_Donald_Trump  \
# 0        Baker      OR                      0.727
# 1       Benton      OR                      0.286
# 2    Clackamas      OR                      0.434
# 3      Clatsop      OR                      0.429
# 4     Columbia      OR                      0.517
# 5         Coos      OR                      0.586
# 6        Crook      OR                      0.721
# 7        Curry      OR                      0.588
# 8    Deschutes      OR                      0.482
# 9      Douglas      OR                      0.664
# 10     Gilliam      OR                      0.674
# 11       Grant      OR                      0.764
# 12      Harney      OR                      0.754
# 13  Hood River      OR                      0.310
# 14     Jackson      OR                      0.511
# 15   Jefferson      OR                      0.601
# 16   Josephine      OR                      0.624
# 17     Klamath      OR                      0.690
# ...

# %%
## solution one - data types? (did not solve the problem, saved for reference)

# %%
# The merge isn't working, suspect the problem is the way "county" is storing the data
# checking the dtypes reveals that the county was stored as an object. 

df_OR_deaths.dtypes
# Out:
# Date-as-of           object
# Start_date           object
# End_date             object
# state                object
# CountyName           object
# FIPS_code             int64
# Urban-Rural_code     object
# Deaths_COVID        float64
# Deaths_All          float64
# Footnote             object
# county               object
# Extra                object
# dtype: object

# %%
# Converting the column type from object to string. |S sets the string length to default to the max length encountered in the dataset

df_OR_deaths['county'] = df_OR_deaths['county'].astype('|S')
# Out:
# C:\Users\abgar\AppData\Local\Temp/ipykernel_41796/1110459575.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_OR_deaths['county'] = df_OR_deaths['county'].astype('|S')

# %%
# Check - dataset converted
df_OR_deaths.dtypes
# Out:
# Date-as-of           object
# Start_date           object
# End_date             object
# state                object
# CountyName           object
# FIPS_code             int64
# Urban-Rural_code     object
# Deaths_COVID        float64
# Deaths_All          float64
# Footnote             object
# county                 |S10
# Extra                object
# dtype: object

# %%
# County also saved as an ojbect in the votes dataset. Converting to a string as well.
df_OR_votes.dtypes
# Out:
# county                           object
# state                            object
# percentage16_Donald_Trump       float64
# percentage16_Hillary_Clinton    float64
# total_votes16                   float64
# votes16_Donald_Trump            float64
# votes16_Hillary_Clinton         float64
# percentage20_Donald_Trump       float64
# percentage20_Joe_Biden          float64
# total_votes20                   float64
# votes20_Donald_Trump            float64
# votes20_Joe_Biden               float64
# lat                             float64
# long                            float64
# cases                           float64
# deaths                          float64
# TotalPop                        float64
# Men                             float64
# Women                           float64
# Hispanic                        float64
# White                           float64
# Black                           float64
# Native                          float64
# ...

# %%
df_OR_votes['county'] = df_OR_votes['county'].astype('|S')
# Out:
# C:\Users\abgar\AppData\Local\Temp/ipykernel_41796/3981743551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_OR_votes['county'] = df_OR_votes['county'].astype('|S')

# %%
df_OR_votes.dtypes
# Out:
# county                             |S10
# state                            object
# percentage16_Donald_Trump       float64
# percentage16_Hillary_Clinton    float64
# total_votes16                   float64
# votes16_Donald_Trump            float64
# votes16_Hillary_Clinton         float64
# percentage20_Donald_Trump       float64
# percentage20_Joe_Biden          float64
# total_votes20                   float64
# votes20_Donald_Trump            float64
# votes20_Joe_Biden               float64
# lat                             float64
# long                            float64
# cases                           float64
# deaths                          float64
# TotalPop                        float64
# Men                             float64
# Women                           float64
# Hispanic                        float64
# White                           float64
# Black                           float64
# Native                          float64
# ...

# %%
df_OR_votes.merge(df_OR_deaths, on='county')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_41796/2260073458.py in <module>
# ----> 1 df_OR_votes.merge(df_OR_deaths, on='county')
#       2
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9189         from pandas.core.reshape.merge import merge
#    9190
# -> 9191         return merge(
#    9192             self,
#    9193             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     118         validate=validate,
#     119     )
# --> 120     return op.get_result()
#     121
#     122
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
# ...

# %%
## Solution:

# SOLVED!! it needed to be sliced on " County", not "County". The resulting columns couldn't match
# because of the hanging " "
