# %%
#Exploring data from the Provisional COVID-19 death counts in the US, by county.

# This dataset includes a snapshot of total deaths recorded between  01/01/2020 and 10/16/2021, as measured in 10/20/2021. 
# It covers data from all counties in the US.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("../data_sources/Provisional_COVID-19_Death_Counts_in_the_United_States_by_County.csv")

# %%
df.head()
# Out:
#    Date as of  Start Date    End Date State             County name  \
# 0  10/20/2021  01/01/2020  10/16/2021    AK  Aleutians East Borough
# 1  10/20/2021  01/01/2020  10/16/2021    AK  Anchorage Municipality
# 2  10/20/2021  01/01/2020  10/16/2021    AK      Bethel Census Area
# 3  10/20/2021  01/01/2020  10/16/2021    AK          Denali Borough
# 4  10/20/2021  01/01/2020  10/16/2021    AK  Dillingham Census Area
#
#    FIPS County Code Urban Rural Code  Deaths involving COVID-19  \
# 0              2013          Noncore                        NaN
# 1              2020     Medium metro                      366.0
# 2              2050          Noncore                       18.0
# 3              2068          Noncore                        NaN
# 4              2070          Noncore                        NaN
#
#    Deaths from All Causes                                           Footnote
# 0                    14.0  One or more data cells have counts between 1-9...
# 1                  4133.0                                                NaN
# 2                   194.0                                                NaN
# 3                    11.0  One or more data cells have counts between 1-9...
# 4                    45.0  One or more data cells have counts between 1-9...

# %%
df.count()
# Out:
# Date as of                   3030
# Start Date                   3030
# End Date                     3030
# State                        3030
# County name                  3030
# FIPS County Code             3030
# Urban Rural Code             3030
# Deaths involving COVID-19    2439
# Deaths from All Causes       3029
# Footnote                      591
# dtype: int64

# %%
df.dtypes
# Out:
# Date as of                    object
# Start Date                    object
# End Date                      object
# State                         object
# County name                   object
# FIPS County Code               int64
# Urban Rural Code              object
# Deaths involving COVID-19    float64
# Deaths from All Causes       float64
# Footnote                      object
# dtype: object

# %%
# Noting: CLEAN UP TASK:
# Dates are objects, and not date types.

# %%
df_new = df.rename(columns={'Date as of':'Date-as-of', 'Start Date':'Start_date', 'End Date': 'End_date',
                            'County name':'county', 'FIPS County Code':'FIPS_code', 'Urban Rural Code':'Urban-Rural_code',
                           'Deaths involving COVID-19':'Deaths_COVID', 'Deaths from All Causes':'Deaths_All'})

# %%
df_new.head()
# Out:
#    Date-as-of  Start_date    End_date State                  county  \
# 0  10/20/2021  01/01/2020  10/16/2021    AK  Aleutians East Borough
# 1  10/20/2021  01/01/2020  10/16/2021    AK  Anchorage Municipality
# 2  10/20/2021  01/01/2020  10/16/2021    AK      Bethel Census Area
# 3  10/20/2021  01/01/2020  10/16/2021    AK          Denali Borough
# 4  10/20/2021  01/01/2020  10/16/2021    AK  Dillingham Census Area
#
#    FIPS_code Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 0       2013          Noncore           NaN        14.0
# 1       2020     Medium metro         366.0      4133.0
# 2       2050          Noncore          18.0       194.0
# 3       2068          Noncore           NaN        11.0
# 4       2070          Noncore           NaN        45.0
#
#                                             Footnote
# 0  One or more data cells have counts between 1-9...
# 1                                                NaN
# 2                                                NaN
# 3  One or more data cells have counts between 1-9...
# 4  One or more data cells have counts between 1-9...

# %%
df_new.dtypes
# Out:
# Date-as-of           object
# Start_date           object
# End_date             object
# State                object
# county               object
# FIPS_code             int64
# Urban-Rural_code     object
# Deaths_COVID        float64
# Deaths_All          float64
# Footnote             object
# dtype: object

# %%
df_new['Date-as-of']=pd.to_datetime(df_new['Date-as-of'])

# %%
df_new.head()
# Out:
#   Date-as-of  Start_date    End_date State                  county  FIPS_code  \
# 0 2021-10-20  01/01/2020  10/16/2021    AK  Aleutians East Borough       2013
# 1 2021-10-20  01/01/2020  10/16/2021    AK  Anchorage Municipality       2020
# 2 2021-10-20  01/01/2020  10/16/2021    AK      Bethel Census Area       2050
# 3 2021-10-20  01/01/2020  10/16/2021    AK          Denali Borough       2068
# 4 2021-10-20  01/01/2020  10/16/2021    AK  Dillingham Census Area       2070
#
#   Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 0          Noncore           NaN        14.0
# 1     Medium metro         366.0      4133.0
# 2          Noncore          18.0       194.0
# 3          Noncore           NaN        11.0
# 4          Noncore           NaN        45.0
#
#                                             Footnote
# 0  One or more data cells have counts between 1-9...
# 1                                                NaN
# 2                                                NaN
# 3  One or more data cells have counts between 1-9...
# 4  One or more data cells have counts between 1-9...

# %%
df_new.dtypes
# Out:
# Date-as-of          datetime64[ns]
# Start_date                  object
# End_date                    object
# State                       object
# county                      object
# FIPS_code                    int64
# Urban-Rural_code            object
# Deaths_COVID               float64
# Deaths_All                 float64
# Footnote                    object
# dtype: object

# %%
df_new['Start_date']=pd.to_datetime(df_new['Start_date'])

# %%
df_new['End_date']=pd.to_datetime(df_new['End_date'])

# %%
df_new.head()
# Out:
#   Date-as-of Start_date   End_date State                  county  FIPS_code  \
# 0 2021-10-20 2020-01-01 2021-10-16    AK  Aleutians East Borough       2013
# 1 2021-10-20 2020-01-01 2021-10-16    AK  Anchorage Municipality       2020
# 2 2021-10-20 2020-01-01 2021-10-16    AK      Bethel Census Area       2050
# 3 2021-10-20 2020-01-01 2021-10-16    AK          Denali Borough       2068
# 4 2021-10-20 2020-01-01 2021-10-16    AK  Dillingham Census Area       2070
#
#   Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 0          Noncore           NaN        14.0
# 1     Medium metro         366.0      4133.0
# 2          Noncore          18.0       194.0
# 3          Noncore           NaN        11.0
# 4          Noncore           NaN        45.0
#
#                                             Footnote
# 0  One or more data cells have counts between 1-9...
# 1                                                NaN
# 2                                                NaN
# 3  One or more data cells have counts between 1-9...
# 4  One or more data cells have counts between 1-9...

# %%
df_new.dtypes
# Out:
# Date-as-of          datetime64[ns]
# Start_date          datetime64[ns]
# End_date            datetime64[ns]
# State                       object
# county                      object
# FIPS_code                    int64
# Urban-Rural_code            object
# Deaths_COVID               float64
# Deaths_All                 float64
# Footnote                    object
# dtype: object

# %%
# check spelling of county names 
# FREQUENCEY = the frequency of the name across all states (ex/ 30 states have a "Washington County")


df_new['county'].value_counts()
# Out:
# Washington County    30
# Jefferson County     25
# Franklin County      23
# Lincoln County       22
# Jackson County       22
#                      ..
# Hampden County        1
# Dukes County          1
# Berkshire County      1
# Barnstable County     1
# Weston County         1
# Name: county, Length: 1811, dtype: int64

# %%
#Isolate unique county names into its own dataframe:

df_new.county.unique()
# Out:
# array(['Aleutians East Borough', 'Anchorage Municipality',
#        'Bethel Census Area', ..., 'Uinta County', 'Washakie County',
#        'Weston County'], dtype=object)

# %%
county_unique = df_new.County_name.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4336/3780623563.py in <module>
# ----> 1 county_unique = df_new.County_name.unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'County_name'

# %%
county_unique
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4336/1837572851.py in <module>
# ----> 1 county_unique
#
# NameError: name 'county_unique' is not defined

# %%
#Isolate unique county names into its own dataframe, take two:
df_counties = pd. DataFrame(county_unique, columns=['County-name'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4336/2119214862.py in <module>
#       1 #Isolate unique county names into its own dataframe:
# ----> 2 df_counties = pd. DataFrame(county_unique, columns=['County-name'])
#
# NameError: name 'county_unique' is not defined

# %%
# MAX Deaths (COVID)
df_new['Deaths_COVID'].max()
# Out:
# 24768.0

# %%
# MAX Deaths (ALL)
df_new['Deaths_All'].max()
# Out:
# 146639.0

# %%
# Confirming all measures ended on the same date, 10-16-2021 (Confirmed)

df_new['End_date'].value_counts()
# Out:
# 2021-10-16    3030
# Name: End_date, dtype: int64

# %%
# SLICE - OREGON Data
oregon_data_df=df_new.loc[df_new["State"]=="OR"]
oregon_data_df
# Out:
#      Date-as-of Start_date   End_date State             county  FIPS_code  \
# 2128 2021-10-20 2020-01-01 2021-10-16    OR       Baker County      41001
# 2129 2021-10-20 2020-01-01 2021-10-16    OR      Benton County      41003
# 2130 2021-10-20 2020-01-01 2021-10-16    OR   Clackamas County      41005
# 2131 2021-10-20 2020-01-01 2021-10-16    OR     Clatsop County      41007
# 2132 2021-10-20 2020-01-01 2021-10-16    OR    Columbia County      41009
# 2133 2021-10-20 2020-01-01 2021-10-16    OR        Coos County      41011
# 2134 2021-10-20 2020-01-01 2021-10-16    OR       Crook County      41013
# 2135 2021-10-20 2020-01-01 2021-10-16    OR       Curry County      41015
# 2136 2021-10-20 2020-01-01 2021-10-16    OR   Deschutes County      41017
# 2137 2021-10-20 2020-01-01 2021-10-16    OR     Douglas County      41019
# 2138 2021-10-20 2020-01-01 2021-10-16    OR     Gilliam County      41021
# 2139 2021-10-20 2020-01-01 2021-10-16    OR       Grant County      41023
# 2140 2021-10-20 2020-01-01 2021-10-16    OR      Harney County      41025
# 2141 2021-10-20 2020-01-01 2021-10-16    OR  Hood River County      41027
# 2142 2021-10-20 2020-01-01 2021-10-16    OR     Jackson County      41029
# 2143 2021-10-20 2020-01-01 2021-10-16    OR   Jefferson County      41031
# 2134                                                NaN
# 2135                                                NaN
# 2136                                                NaN
# 2137                                                NaN
# 2138  One or more data cells have counts between 1-9...
# 2139  One or more data cells have counts between 1-9...
# 2140                                                NaN
# 2141                                                NaN
# 2142                                                NaN
# 2143                                                NaN
# 2144                                                NaN
# 2145                                                NaN
# 2146                                                NaN
# 2147                                                NaN
# 2148                                                NaN
# 2149                                                NaN
# 2150                                                NaN
# 2151                                                NaN
# 2152  One or more data cells have counts between 1-9...
# 2153                                                NaN
# 2154                                                NaN
# 2155                                                NaN
# 2156                                                NaN
# 2157                                                NaN
# 2158  One or more data cells have counts between 1-9...
# 2159                                                NaN
# 2160                                                NaN
# 2161                                                NaN

# %%
oregon_data_df['new column']=(oregon_data_df['Deaths_COVID']/oregon_data_df['Deaths_All'])*100
# Out:
# C:\Users\abgar\AppData\Local\Temp/ipykernel_4336/1655000216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oregon_data_df['new column']=(oregon_data_df['Deaths_COVID']/oregon_data_df['Deaths_All'])*100

# %%
df_new2 = df_new

# %%
df_new2['%Deaths_Covid']=(df_new2['Deaths_COVID']/df_new2['Deaths_All'])*100

# %%
df_new2.head()
# Out:
#   Date-as-of Start_date   End_date State                  county  FIPS_code  \
# 0 2021-10-20 2020-01-01 2021-10-16    AK  Aleutians East Borough       2013
# 1 2021-10-20 2020-01-01 2021-10-16    AK  Anchorage Municipality       2020
# 2 2021-10-20 2020-01-01 2021-10-16    AK      Bethel Census Area       2050
# 3 2021-10-20 2020-01-01 2021-10-16    AK          Denali Borough       2068
# 4 2021-10-20 2020-01-01 2021-10-16    AK  Dillingham Census Area       2070
#
#   Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 0          Noncore           NaN        14.0
# 1     Medium metro         366.0      4133.0
# 2          Noncore          18.0       194.0
# 3          Noncore           NaN        11.0
# 4          Noncore           NaN        45.0
#
#                                             Footnote  new column  \
# 0  One or more data cells have counts between 1-9...         NaN
# 1                                                NaN    8.855553
# 2                                                NaN    9.278351
# 3  One or more data cells have counts between 1-9...         NaN
# 4  One or more data cells have counts between 1-9...         NaN
#
#    %Deaths_Covid
# 0            NaN
# 1       8.855553
# 2       9.278351
# 3            NaN
# 4            NaN

# %%
df_new2=df_new2.drop(columns=['new column'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4336/3254108809.py in <module>
# ----> 1 df_new2=df_new2.drop(columns=['new column'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['new column'] not found in axis"

# %%
df_new2.head()
# Out:
#   Date-as-of Start_date   End_date State                  county  FIPS_code  \
# 0 2021-10-20 2020-01-01 2021-10-16    AK  Aleutians East Borough       2013
# 1 2021-10-20 2020-01-01 2021-10-16    AK  Anchorage Municipality       2020
# 2 2021-10-20 2020-01-01 2021-10-16    AK      Bethel Census Area       2050
# 3 2021-10-20 2020-01-01 2021-10-16    AK          Denali Borough       2068
# 4 2021-10-20 2020-01-01 2021-10-16    AK  Dillingham Census Area       2070
#
#   Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 2158 2021-10-20 2020-01-01 2021-10-16    OR     Wallowa County      41063
# 2159 2021-10-20 2020-01-01 2021-10-16    OR       Wasco County      41065
# 2160 2021-10-20 2020-01-01 2021-10-16    OR  Washington County      41067
# 2161 2021-10-20 2020-01-01 2021-10-16    OR     Yamhill County      41071
#
#          Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 2128              Noncore           NaN       390.0
# 2129          Small metro          69.0      1300.0
# 2130   Large fringe metro         321.0      6544.0
# 2131         Micropolitan          20.0       724.0
# 2132   Large fringe metro          15.0       507.0
# 2133         Micropolitan          55.0      1603.0
# 2134         Micropolitan          16.0       401.0
# 2135         Micropolitan          18.0       667.0
# 2136          Small metro         244.0      3328.0
# 2137         Micropolitan         183.0      2924.0
# 2138              Noncore           NaN        24.0
# 2139              Noncore           NaN       152.0
# 2140              Noncore          14.0       143.0
# 2141         Micropolitan          25.0       325.0
# 2142          Small metro         309.0      4961.0
# 2143              Noncore          13.0       389.0
# 2144          Small metro         198.0      2359.0
# 2145         Micropolitan         109.0      1606.0
# 2146              Noncore          10.0       182.0
# 2147         Medium metro         302.0      7762.0
# 2148         Micropolitan          27.0      1006.0
# 2149          Small metro          97.0      2547.0
# 2150         Micropolitan          26.0       535.0
# 2151         Medium metro         406.0      5658.0
# 2152         Micropolitan           NaN        98.0
# 2153  Large central metro        1089.0     13822.0
# 2154         Medium metro          31.0      1037.0
# 2155              Noncore          20.0       573.0
# 2156         Micropolitan          93.0      1173.0
# 2157         Micropolitan          31.0       492.0
# 2158              Noncore           NaN       130.0
# 2159         Micropolitan          40.0       621.0
# 2160   Large fringe metro         432.0      6972.0
# 2161   Large fringe metro          94.0      1776.0
#
#                                                Footnote  %Deaths_Covid
# 2128  One or more data cells have counts between 1-9...            NaN
# 2129                                                NaN       5.307692
# 2130                                                NaN       4.905257
# 2131                                                NaN       2.762431
# 2132                                                NaN       2.958580
# 2133                                                NaN       3.431067
# 2134                                                NaN       3.990025
# 2135                                                NaN       2.698651
# 2136                                                NaN       7.331731
# 2137                                                NaN       6.258550
# 2138  One or more data cells have counts between 1-9...            NaN
# 2139  One or more data cells have counts between 1-9...            NaN
# 2140                                                NaN       9.790210
# 2141                                                NaN       7.692308
# 2142                                                NaN       6.228583
# 2143                                                NaN       3.341902
# 2144                                                NaN       8.393387
# 2145                                                NaN       6.787049
# 2146                                                NaN       5.494505
# 2147                                                NaN       3.890750
# 2148                                                NaN       2.683897
# 2149                                                NaN       3.808402
# 2150                                                NaN       4.859813
# 2151                                                NaN       7.175680
# 2152  One or more data cells have counts between 1-9...            NaN
# 2153                                                NaN       7.878744
# 2154                                                NaN       2.989392
# 2155                                                NaN       3.490401
# 2156                                                NaN       7.928389
# 2157                                                NaN       6.300813
# 2158  One or more data cells have counts between 1-9...            NaN
# 2159                                                NaN       6.441224
# 2160                                                NaN       6.196213
# 2161                                                NaN       5.292793
