# %%
# first whack at visualizations; OREGON focused

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# VOTES

# Read in voting data and set up initial voting dataframe

df_votes = pd.read_csv("../data_sources/elections_by_county_Eric.csv")
df_votes.head()
# Out:
#       county state  percentage16_Donald_Trump  percentage16_Hillary_Clinton  \
# 0  Abbeville    SC                      0.629                         0.346
# 1     Acadia    LA                      0.773                         0.206
# 2   Accomack    VA                      0.545                         0.428
# 3        Ada    ID                      0.479                         0.387
# 4      Adair    IA                      0.653                         0.300
#
#    total_votes16  votes16_Donald_Trump  votes16_Hillary_Clinton  \
# 0        10724.0                6742.0                   3712.0
# 1        27386.0               21159.0                   5638.0
# 2        15755.0                8582.0                   6737.0
# 3       195587.0               93748.0                  75676.0
# 4         3759.0                2456.0                   1127.0
#
#    percentage20_Donald_Trump  percentage20_Joe_Biden  total_votes20  ...  \
# ...

# %%
# select oregon voting data
df_OR_votes = df_votes[df_votes.state == 'OR']
df_OR_votes.head()
# Out:
#         county state  percentage16_Donald_Trump  percentage16_Hillary_Clinton  \
# 115      Baker    OR                      0.727                         0.210
# 183     Benton    OR                      0.286                         0.624
# 507  Clackamas    OR                      0.434                         0.495
# 532    Clatsop    OR                      0.429                         0.490
# 604   Columbia    OR                      0.517                         0.397
#
#      total_votes16  votes16_Donald_Trump  votes16_Hillary_Clinton  \
# 115         8479.0                6160.0                   1781.0
# 183        45577.0               13030.0                  28431.0
# 507       182136.0               79062.0                  90187.0
# 532        18158.0                7794.0                   8899.0
# 604        25077.0               12967.0                   9959.0
#
#      percentage20_Donald_Trump  percentage20_Joe_Biden  total_votes20  ...  \
# ...

# %%
# Deaths

# read in Death data and prep initial dataframe

df_deaths = pd.read_csv("../data_sources/Provisional_COVID-19_Death_Counts_in_the_United_States_by_County.csv")

df_deaths= df_deaths.rename(columns={'Date as of':'Date-as-of', 'Start Date':'Start_date', 'End Date': 'End_date', 'State':'state',
                            'County name':'CountyName', 'FIPS County Code':'FIPS_code', 'Urban Rural Code':'Urban-Rural_code',
                           'Deaths involving COVID-19':'Deaths_COVID', 'Deaths from All Causes':'Deaths_All'})

df_deaths.head()
# Out:
#    Date-as-of  Start_date    End_date state              CountyName  \
# 0  10/20/2021  01/01/2020  10/16/2021    AK  Aleutians East Borough
# 1  10/20/2021  01/01/2020  10/16/2021    AK  Anchorage Municipality
# 2  10/20/2021  01/01/2020  10/16/2021    AK      Bethel Census Area
# 3  10/20/2021  01/01/2020  10/16/2021    AK          Denali Borough
# 4  10/20/2021  01/01/2020  10/16/2021    AK  Dillingham Census Area
#
#    FIPS_code Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 0       2013          Noncore           NaN        14.0
# 1       2020     Medium metro         366.0      4133.0
# 2       2050          Noncore          18.0       194.0
# 3       2068          Noncore           NaN        11.0
# 4       2070          Noncore           NaN        45.0
#
#                                             Footnote
# 0  One or more data cells have counts between 1-9...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
#select Oregon Death statistics

df_OR_deaths = df_deaths[df_deaths.state == 'OR']
df_OR_deaths.head()
# Out:
#       Date-as-of  Start_date    End_date state        CountyName  FIPS_code  \
# 2128  10/20/2021  01/01/2020  10/16/2021    OR      Baker County      41001
# 2129  10/20/2021  01/01/2020  10/16/2021    OR     Benton County      41003
# 2130  10/20/2021  01/01/2020  10/16/2021    OR  Clackamas County      41005
# 2131  10/20/2021  01/01/2020  10/16/2021    OR    Clatsop County      41007
# 2132  10/20/2021  01/01/2020  10/16/2021    OR   Columbia County      41009
#
#         Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 2128             Noncore           NaN       390.0
# 2129         Small metro          69.0      1300.0
# 2130  Large fringe metro         321.0      6544.0
# 2131        Micropolitan          20.0       724.0
# 2132  Large fringe metro          15.0       507.0
#
#                                                Footnote
# 2128  One or more data cells have counts between 1-9...
# 2129                                                NaN
# ...

# %%
df_OR_deaths[['county','Extra']] = df_OR_deaths.CountyName.str.split(" County",expand=True,)
df_OR_deaths.head()
# Out:
# C:\Users\abgar\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#       Date-as-of  Start_date    End_date state        CountyName  FIPS_code  \
# 2128  10/20/2021  01/01/2020  10/16/2021    OR      Baker County      41001
# 2129  10/20/2021  01/01/2020  10/16/2021    OR     Benton County      41003
# 2130  10/20/2021  01/01/2020  10/16/2021    OR  Clackamas County      41005
# 2131  10/20/2021  01/01/2020  10/16/2021    OR    Clatsop County      41007
# 2132  10/20/2021  01/01/2020  10/16/2021    OR   Columbia County      41009
#
#         Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 2128             Noncore           NaN       390.0
# ...

# %%
# Merge data frames
merged_orgeon = pd.merge(df_OR_votes,df_OR_deaths, how='outer', on='county')

# %%
merged_orgeon
# Out:
#         county state_x  percentage16_Donald_Trump  \
# 0        Baker      OR                      0.727
# 1       Benton      OR                      0.286
# 2    Clackamas      OR                      0.434
# 3      Clatsop      OR                      0.429
# 4     Columbia      OR                      0.517
# 5         Coos      OR                      0.586
# 6        Crook      OR                      0.721
# 7        Curry      OR                      0.588
# 8    Deschutes      OR                      0.482
# 9      Douglas      OR                      0.664
# 10     Gilliam      OR                      0.674
# 11       Grant      OR                      0.764
# 12      Harney      OR                      0.754
# 13  Hood River      OR                      0.310
# 14     Jackson      OR                      0.511
# 15   Jefferson      OR                      0.601
# 16   Josephine      OR                      0.624
# 17     Klamath      OR                      0.690
# ...

# %%
# SEABORN - Barchart

sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
#crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total deaths
sns.set_color_codes("pastel")
sns.barplot(x="Deaths_All", y="county", data=merged_orgeon,
            label="Total Deaths", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="Deaths_COVID", y="county", data=merged_orgeon,
            label="COVID Deaths", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 10000), ylabel="",
       xlabel="Deaths by County")
sns.despine(left=True, bottom=True)

# %%
merged_orgeon
# Out:
#         county state_x  percentage16_Donald_Trump  \
# 0        Baker      OR                      0.727
# 1       Benton      OR                      0.286
# 2    Clackamas      OR                      0.434
# 3      Clatsop      OR                      0.429
# 4     Columbia      OR                      0.517
# 5         Coos      OR                      0.586
# 6        Crook      OR                      0.721
# 7        Curry      OR                      0.588
# 8    Deschutes      OR                      0.482
# 9      Douglas      OR                      0.664
# 10     Gilliam      OR                      0.674
# 11       Grant      OR                      0.764
# 12      Harney      OR                      0.754
# 13  Hood River      OR                      0.310
# 14     Jackson      OR                      0.511
# 15   Jefferson      OR                      0.601
# 16   Josephine      OR                      0.624
# 17     Klamath      OR                      0.690
# ...

# %%
merged_orgeon.Deaths_COVID
# Out:
# 0        NaN
# 1       69.0
# 2      321.0
# 3       20.0
# 4       15.0
# 5       55.0
# 6       16.0
# 7       18.0
# 8      244.0
# 9      183.0
# 10       NaN
# 11       NaN
# 12      14.0
# 13      25.0
# 14     309.0
# 15      13.0
# 16     198.0
# 17     109.0
# 18      10.0
# 19     302.0
# 20      27.0
# 21      97.0
# 22      26.0
# 23     406.0
# 24       NaN
# 25    1089.0
# 26      31.0
# 27       NaN
# 28      20.0
# 29      93.0
# 30      31.0
# 31       NaN
# 32      40.0
# 33     432.0
# 34       NaN
# 35      94.0
# 36       NaN
# 37       NaN
# Name: Deaths_COVID, dtype: float64

# %%
merged_orgeon.Deaths_All
# Out:
# 0       390.0
# 1      1300.0
# 2      6544.0
# 3       724.0
# 4       507.0
# 5      1603.0
# 6       401.0
# 7       667.0
# 8      3328.0
# 9      2924.0
# 10       24.0
# 11      152.0
# 12      143.0
# 13      325.0
# 14     4961.0
# 15      389.0
# 16     2359.0
# 17     1606.0
# 18      182.0
# 19     7762.0
# 20     1006.0
# 21     2547.0
# 22      535.0
# 23     5658.0
# 24       98.0
# 25    13822.0
# 26     1037.0
# 27        NaN
# 28      573.0
# 29     1173.0
# 30      492.0
# 31      130.0
# 32      621.0
# 33     6972.0
# 34        NaN
# 35     1776.0
# 36        NaN
# 37        NaN
# Name: Deaths_All, dtype: float64

# %%
merged_orgeon["Deaths_proportional"]=(merged_orgeon.Deaths_COVID/merged_orgeon.Deaths_All)

# %%
merged_orgeon
# Out:
#         county state_x  percentage16_Donald_Trump  \
# 0        Baker      OR                      0.727
# 1       Benton      OR                      0.286
# 2    Clackamas      OR                      0.434
# 3      Clatsop      OR                      0.429
# 4     Columbia      OR                      0.517
# 5         Coos      OR                      0.586
# 6        Crook      OR                      0.721
# 7        Curry      OR                      0.588
# 8    Deschutes      OR                      0.482
# 9      Douglas      OR                      0.664
# 10     Gilliam      OR                      0.674
# 11       Grant      OR                      0.764
# 12      Harney      OR                      0.754
# 13  Hood River      OR                      0.310
# 14     Jackson      OR                      0.511
# 15   Jefferson      OR                      0.601
# 16   Josephine      OR                      0.624
# 17     Klamath      OR                      0.690
# ...

# %%
# SEABORN - Barchart II

sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))


# Plot the percentage for DT
sns.set_color_codes("muted")
sns.barplot(x="percentage20_Donald_Trump", y="county", data=merged_orgeon,
            label="Percentage 20 DT", color="b")

# Plot the total deaths
sns.set_color_codes("pastel")
sns.barplot(x="Deaths_proportional", y="county", data=merged_orgeon,
            label="Proportional COVID Deaths", color="b")



# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 1.5), ylabel="",
       xlabel="Deaths by County")
sns.despine(left=True, bottom=True)

# %%
# SEABORN - Barchart III

sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Plot the percentage for DT
sns.set_color_codes("pastel")
sns.barplot(x="percentage16_Donald_Trump", y="county", data=merged_orgeon,
            label="Percentage 16 DT", color="g")

# Plot the percentage for DT
sns.set_color_codes("muted")
sns.barplot(x="percentage20_Donald_Trump", y="county", data=merged_orgeon,
            label="Percentage 20 DT", color="b")




# Plot the total deaths
sns.set_color_codes("pastel")
sns.barplot(x="Deaths_proportional", y="county", data=merged_orgeon,
            label="Proportional COVID Deaths", color="b")



# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 1.5), ylabel="",
       xlabel="Deaths by County")
sns.despine(left=True, bottom=True)

# %%
## NEXT STEPS:
# determine if there is a statistical relationship betweent the 2020 and/or 2016 DT votes and percentage deaths? 
# (investigating if there is a relationship between voting patterns and COVID deaths. Test total deaths; total votes; 
# percentages & rate of change (2016/2020)
