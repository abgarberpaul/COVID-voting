# %%
#Exploring data from the Elections by County, as shared by Eric  .

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("../data_sources/elections_by_county_Eric.csv")

# %%
df.head()
# Out:
#       county state  percentage16_Donald_Trump  percentage16_Hillary_Clinton  \
# 0  Abbeville    SC                      0.629                         0.346
# 1     Acadia    LA                      0.773                         0.206
# 2   Accomack    VA                      0.545                         0.428
# 3        Ada    ID                      0.479                         0.387
# 4      Adair    IA                      0.653                         0.300
#
#    total_votes16  votes16_Donald_Trump  votes16_Hillary_Clinton  \
# 0        10724.0                6742.0                   3712.0
# 1        27386.0               21159.0                   5638.0
# 2        15755.0                8582.0                   6737.0
# 3       195587.0               93748.0                  75676.0
# 4         3759.0                2456.0                   1127.0
#
#    percentage20_Donald_Trump  percentage20_Joe_Biden  total_votes20  ...  \
# ...

# %%
# SLICE - OREGON Data
oregon_votes_df=df.loc[df["state"]=="OR"]
oregon_votes_df
# Out:
#           county state  percentage16_Donald_Trump  \
# 115        Baker    OR                      0.727
# 183       Benton    OR                      0.286
# 507    Clackamas    OR                      0.434
# 532      Clatsop    OR                      0.429
# 604     Columbia    OR                      0.517
# 628         Coos    OR                      0.586
# 668        Crook    OR                      0.721
# 688        Curry    OR                      0.588
# 765    Deschutes    OR                      0.482
# 807      Douglas    OR                      0.664
# 1032     Gilliam    OR                      0.674
# 1079       Grant    OR                      0.764
# 1196      Harney    OR                      0.754
# 1277  Hood River    OR                      0.310
# 1368     Jackson    OR                      0.511
# 1405   Jefferson    OR                      0.601
# 1445   Josephine    OR                      0.624
# 1505     Klamath    OR                      0.690
# ...

# %%
oregon_votes_df['county']
# Out:
# 115          Baker
# 183         Benton
# 507      Clackamas
# 532        Clatsop
# 604       Columbia
# 628           Coos
# 668          Crook
# 688          Curry
# 765      Deschutes
# 807        Douglas
# 1032       Gilliam
# 1079         Grant
# 1196        Harney
# 1277    Hood River
# 1368       Jackson
# 1405     Jefferson
# 1445     Josephine
# 1505       Klamath
# 1551          Lake
# 1568          Lane
# 1659       Lincoln
# 1670          Linn
# 1759       Malheur
# 1783        Marion
# 2000        Morrow
# 2008     Multnomah
# 2279          Polk
# 2579       Sherman
# 2765     Tillamook
# 2821      Umatilla
# 2835         Union
# 2890       Wallowa
# 2917         Wasco
# 2942    Washington
# 3005       Wheeler
# 3088       Yamhill
# 4765     Out of OR
# 4766    Unassigned
# Name: county, dtype: object
