# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# VOTES
df_votes = pd.read_csv("../data_sources/elections_by_county_Eric.csv")

# %%
# SLICE - OREGON Data (votes)
oregon_votes_df=df_votes.loc[df_votes["state"]=="OR"]
oregon_votes_df.head()
# Out:
#         county state  percentage16_Donald_Trump  percentage16_Hillary_Clinton  \
# 115      Baker    OR                      0.727                         0.210
# 183     Benton    OR                      0.286                         0.624
# 507  Clackamas    OR                      0.434                         0.495
# 532    Clatsop    OR                      0.429                         0.490
# 604   Columbia    OR                      0.517                         0.397
#
#      total_votes16  votes16_Donald_Trump  votes16_Hillary_Clinton  \
# 115         8479.0                6160.0                   1781.0
# 183        45577.0               13030.0                  28431.0
# 507       182136.0               79062.0                  90187.0
# 532        18158.0                7794.0                   8899.0
# 604        25077.0               12967.0                   9959.0
#
#      percentage20_Donald_Trump  percentage20_Joe_Biden  total_votes20  ...  \
# ...

# %%
# Deaths
df_deaths = pd.read_csv("../data_sources/Provisional_COVID-19_Death_Counts_in_the_United_States_by_County.csv")

df_deaths= df_deaths.rename(columns={'Date as of':'Date-as-of', 'Start Date':'Start_date', 'End Date': 'End_date',
                            'County name':'county', 'FIPS County Code':'FIPS_code', 'Urban Rural Code':'Urban-Rural_code',
                           'Deaths involving COVID-19':'Deaths_COVID', 'Deaths from All Causes':'Deaths_All'})

df_deaths.head()
# Out:
#    Date-as-of  Start_date    End_date State                  county  \
# 0  10/20/2021  01/01/2020  10/16/2021    AK  Aleutians East Borough
# 1  10/20/2021  01/01/2020  10/16/2021    AK  Anchorage Municipality
# 2  10/20/2021  01/01/2020  10/16/2021    AK      Bethel Census Area
# 3  10/20/2021  01/01/2020  10/16/2021    AK          Denali Borough
# 4  10/20/2021  01/01/2020  10/16/2021    AK  Dillingham Census Area
#
#    FIPS_code Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 0       2013          Noncore           NaN        14.0
# 1       2020     Medium metro         366.0      4133.0
# 2       2050          Noncore          18.0       194.0
# 3       2068          Noncore           NaN        11.0
# 4       2070          Noncore           NaN        45.0
#
#                                             Footnote
# 0  One or more data cells have counts between 1-9...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
# SLICE - OREGON Data
oregon_deaths_df=df_deaths.loc[df_deaths["State"]=="OR"]
oregon_deaths_df.head()
# Out:
#       Date-as-of  Start_date    End_date State            county  FIPS_code  \
# 2128  10/20/2021  01/01/2020  10/16/2021    OR      Baker County      41001
# 2129  10/20/2021  01/01/2020  10/16/2021    OR     Benton County      41003
# 2130  10/20/2021  01/01/2020  10/16/2021    OR  Clackamas County      41005
# 2131  10/20/2021  01/01/2020  10/16/2021    OR    Clatsop County      41007
# 2132  10/20/2021  01/01/2020  10/16/2021    OR   Columbia County      41009
#
#         Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 2128             Noncore           NaN       390.0
# 2129         Small metro          69.0      1300.0
# 2130  Large fringe metro         321.0      6544.0
# 2131        Micropolitan          20.0       724.0
# 2132  Large fringe metro          15.0       507.0
#
#                                                Footnote
# 2128  One or more data cells have counts between 1-9...
# 2129                                                NaN
# ...

# %%
oregon_deaths_df.shape
# Out:
# (34, 10)

# %%
oregon_votes_df.shape
# Out:
# (38, 50)

# %%
outer_merged_oregon = pd.merge(oregon_deaths_df, oregon_votes_df, how="left", on=['county'])

# %%
outer_merged_oregon.head()
# Out:
#    Date-as-of  Start_date    End_date State            county  FIPS_code  \
# 0  10/20/2021  01/01/2020  10/16/2021    OR      Baker County      41001
# 1  10/20/2021  01/01/2020  10/16/2021    OR     Benton County      41003
# 2  10/20/2021  01/01/2020  10/16/2021    OR  Clackamas County      41005
# 3  10/20/2021  01/01/2020  10/16/2021    OR    Clatsop County      41007
# 4  10/20/2021  01/01/2020  10/16/2021    OR   Columbia County      41009
#
#      Urban-Rural_code  Deaths_COVID  Deaths_All  \
# 0             Noncore           NaN       390.0
# 1         Small metro          69.0      1300.0
# 2  Large fringe metro         321.0      6544.0
# 3        Micropolitan          20.0       724.0
# 4  Large fringe metro          15.0       507.0
#
#                                             Footnote  ... Walk  OtherTransp  \
# 0  One or more data cells have counts between 1-9...  ...  NaN          NaN
# 1                                                NaN  ...  NaN          NaN
# ...

# %%
# FOUND CLEAN UP ISSUE = County is recorded as "Baker" in one, "Baker County" in other...

oregon_deaths_df.county.str.split(expand=True)

# Catches "Hood River" - would it be easier to add "County to the other data set?
# Out:
#                0       1       2
# 2128       Baker  County    None
# 2129      Benton  County    None
# 2130   Clackamas  County    None
# 2131     Clatsop  County    None
# 2132    Columbia  County    None
# 2133        Coos  County    None
# 2134       Crook  County    None
# 2135       Curry  County    None
# 2136   Deschutes  County    None
# 2137     Douglas  County    None
# 2138     Gilliam  County    None
# 2139       Grant  County    None
# 2140      Harney  County    None
# 2141        Hood   River  County
# 2142     Jackson  County    None
# 2143   Jefferson  County    None
# 2144   Josephine  County    None
# 2145     Klamath  County    None
# 2146        Lake  County    None
# 2147        Lane  County    None
# 2148     Lincoln  County    None
# 2149        Linn  County    None
# 2150     Malheur  County    None
# 2151      Marion  County    None
# 2152      Morrow  County    None
# 2153   Multnomah  County    None
# 2154        Polk  County    None
# ...

# %%
# SPLIT "COUNTY" Off evenly, even HOOD RIVER

oregon_deaths_df['county'].str.split('County', expand=True)
# Out:
#                 0 1
# 2128       Baker
# 2129      Benton
# 2130   Clackamas
# 2131     Clatsop
# 2132    Columbia
# 2133        Coos
# 2134       Crook
# 2135       Curry
# 2136   Deschutes
# 2137     Douglas
# 2138     Gilliam
# 2139       Grant
# 2140      Harney
# 2141  Hood River
# 2142     Jackson
# 2143   Jefferson
# 2144   Josephine
# 2145     Klamath
# 2146        Lake
# 2147        Lane
# 2148     Lincoln
# 2149        Linn
# 2150     Malheur
# 2151      Marion
# 2152      Morrow
# 2153   Multnomah
# 2154        Polk
# 2155   Tillamook
# 2156    Umatilla
# 2157       Union
# 2158     Wallowa
# 2159       Wasco
# 2160  Washington
# 2161     Yamhill

# %%
#save as a new column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'New'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#dead end - loc/iloc doesn't lead to appropriate dataframe
